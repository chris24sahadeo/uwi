# %% [markdown]
# # Lab Exam Question Paper
#
# ***
# # Solutions (100%)
# - [PartA.py](PartA.py)
# - [PartB.py](PartB.py)
#
# ***
# # Lab Exam Hints
# Topics covered in labs up to and including outlier detection with DBSCAN
#
# Isolated forests and LOF will **NOT be tested**
#
# All of **classification** and **clustering**:
# - Decision tree
# - Naïve bayes
# - $k$-NN
# - $k$-means
# - DBSCAN
#
# ***
#
# Required to know mainly `sklearn` implementations
# **Will not have to implement algorithms from scratch**
# Need to know accuracy testing stuff:
# - KFold
# - Confusion Matrix
# - Accuracy Score
# - F1 Score
# - Classification Report
#
# May have to use the `iris` dataset from Dr Kieu's website
# And know how to use `label_encoder` (converting words to numbers)
#
# ***
#
#
# #### MUST LEARN: [Practical Business Python](http://pbpython.com/categorical-encoding.html)
# Focus on:
# - Find and replace (mapping words to numbers)
# - Label encoder
# - One hot encoding
#
# ***
#
# Know how to use `pandas` data frames:
# - Dataset
# - Printing heads
# - Cleaning data
#
#
# Plotting graphs with `matplotlib`
#
# Random data generation with `make_blobs`
#
# **We will be allowed to use online documentation during the exam**

# %% [markdown]
# ## Links to relevant docs
# - [Python](https://docs.python.org/3/tutorial/index.html)
#     - [Data Structures](https://docs.python.org/3/tutorial/datastructures.html)
#
# - `sklearn`
#     - Data genertion
#         - [`sklearn.datasets.make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html)
#         - [`sklearn.model_selection.train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#         - [`sklearn.preprocessing.LabelEncoder`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)
#     - Classification Metrics
#         - [`sklearn.model_selection.KFold`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)
#         - [`sklearn.metrics.confusion_matrix`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)
#         - [`sklearn.metrics.accuracy_score`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#         - [`sklearn.metrics.f1_score`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)
#         - [`sklearn.metrics.classification_report`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
#
#     - Classification
#         - [`sklearn.tree.DecisionTreeClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#         - [`sklearn.naive_bayes.GaussianNB`](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)
#         -[`sklearn.neighbors.KNeighborsClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)
#             - [`sklearn.preprocessing.Normalizer`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.Normalizer.html)
#
#     - Clustering
#         - [`sklearn.cluster.KMeans`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
#         - [`sklearn.cluster.DBSCAN`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html)
#             - [`sklearn.preprocessing.StandardScaler` (for outlier detection)](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
#     - t-SNE
#          - [`sklearn.manifold.TSNE`](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html)
#
#
#
# - [`pandas`](https://pandas.pydata.org/pandas-docs/stable/10min.html)
# - [`numpy`](https://docs.scipy.org/doc/numpy-1.13.0/reference/)
# - [`matplotlib.pyplot`](https://matplotlib.org/tutorials/index.html)
